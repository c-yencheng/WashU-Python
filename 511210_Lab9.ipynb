# %% [markdown]
# # Advanced Pandas -- Part 1
#
# In this set of practice exercises, we will be working with a demographic data regarding the passengers aboard the Titanic.  Read in the data frame and use the head() method to check that it was read in correctly.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Import the Titanic.csv file into pandas as df_titanic

# %%
#Write your code here
import pandas as pd
df_titanic = pd.read_csv("Data/Titanic.csv",header=0)
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# Use the rename method to change the column "Sex" to "Gender" and the column "Pclass" to "PassengerClass".

# %%
#Write your code here
df_titanic.rename(columns={"Sex":"Gender","Pclass":"PassengerClass"},inplace=True)
df_titanic
# Out:
#      PassengerId  PassengerClass  \
# 0            892               3
# 1            893               3
# 2            894               2
# 3            895               3
# 4            896               3
# ..           ...             ...
# 413         1305               3
# 414         1306               1
# 415         1307               3
# 416         1308               3
# 417         1309               3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %% [markdown]
# Change the index of the df_titanic to the column Name.

# %%
#Write your code here
df_titanic.set_index("Name",inplace=True)
df_titanic
# Out:
#                                               PassengerId  PassengerClass  \
# Name
# Kelly, Mr. James                                      892               3
# Wilkes, Mrs. James (Ellen Needs)                      893               3
# Myles, Mr. Thomas Francis                             894               2
# Wirz, Mr. Albert                                      895               3
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896               3
# ...                                                   ...             ...
# Spector, Mr. Woolf                                   1305               3
# Oliva y Ocana, Dona. Fermina                         1306               1
# Saether, Mr. Simon Sivertsen                         1307               3
# Ware, Mr. Frederick                                  1308               3
# Peter, Master. Michael J                             1309               3
#
# ...

# %% [markdown]
# Find the age of Oliva y Ocana, Dona. Fermina

# %%
#Write your code here
df_titanic.loc["Oliva y Ocana, Dona. Fermina","Age"]
# Out:
# 39.0

# %% [markdown]
# Change the index back to row numbers but making sure that we don't lose the Name column.

# %%
#Write your code here

df_titanic.reset_index(drop=False,inplace=True)
df_titanic
# Out:
#                                              Name  PassengerId  \
# 0                                Kelly, Mr. James          892
# 1                Wilkes, Mrs. James (Ellen Needs)          893
# 2                       Myles, Mr. Thomas Francis          894
# 3                                Wirz, Mr. Albert          895
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896
# ..                                            ...          ...
# 413                            Spector, Mr. Woolf         1305
# 414                  Oliva y Ocana, Dona. Fermina         1306
# 415                  Saether, Mr. Simon Sivertsen         1307
# 416                           Ware, Mr. Frederick         1308
# 417                      Peter, Master. Michael J         1309
#
#      PassengerClass  Gender   Age  SibSp  Parch              Ticket      Fare  \
# 0                 3    male  34.5      0      0              330911    7.8292
# ...

# %% [markdown]
# How many missing entries are there in the Age column? Use the isnull() method and recall that Booleans are exactly like 1s (True) and 0s (False).

# %%
#Write you code here
df_titanic["Age"].isnull().sum()
# Out:
# 86

# %% [markdown]
# Compute the median age of passengers ignoring the missing data.

# %%
#Write your code here
median_age=df_titanic["Age"].median()
median_age
# Out:
# 27.0

# %% [markdown]
# Using the fillna() method replace the missing values in the Age column with the median.

# %%
#Write your code here
df_titanic["Age"].fillna(median_age,inplace=True)
df_titanic.head()
# Out:
#                                            Name  PassengerId  PassengerClass  \
# 0                              Kelly, Mr. James          892               3
# 1              Wilkes, Mrs. James (Ellen Needs)          893               3
# 2                     Myles, Mr. Thomas Francis          894               2
# 3                              Wirz, Mr. Albert          895               3
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896               3
#
#    Gender   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# Slice the first five rows and store the result as top_5, slice the bottom five rows and store the result as bottom_5.

# %%
#Write your code here
top_5=df_titanic.head(5)
bottom_5=df_titanic.tail(5)

# %% [markdown]
# Concatenate top_5 and bottom_5 and store the result in a variable called concat_1.(Note: Stack the top_5 on top of the bottom_5)

# %%
#Write your code here
concat_1=pd.concat([top_5,bottom_5],axis=0)
concat_1
# Out:
#                                              Name  PassengerId  \
# 0                                Kelly, Mr. James          892
# 1                Wilkes, Mrs. James (Ellen Needs)          893
# 2                       Myles, Mr. Thomas Francis          894
# 3                                Wirz, Mr. Albert          895
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896
# 413                            Spector, Mr. Woolf         1305
# 414                  Oliva y Ocana, Dona. Fermina         1306
# 415                  Saether, Mr. Simon Sivertsen         1307
# 416                           Ware, Mr. Frederick         1308
# 417                      Peter, Master. Michael J         1309
#
#      PassengerClass  Gender   Age  SibSp  Parch              Ticket      Fare  \
# 0                 3    male  34.5      0      0              330911    7.8292
# 1                 3  female  47.0      1      0              363272    7.0000
# ...

# %% [markdown]
# Slice rows 5,10,15 and 20 and columns 'Name' to 'Age' and store the result in variable called count_1. Slice the same rows and columns 'SibSp' to 'Embarked' and store the result in a variable called count_2.

# %%
#Write your code here
count_1=df_titanic.loc[[5,10,15,20],'Name':'Age']
count_2=df_titanic.loc[[5,10,15,20],'SibSp':'Embarked']
count_1,count_2
# Out:
# (                                             Name  PassengerId  \
#  5                      Svensson, Mr. Johan Cervin          897
#  10                               Ilieff, Mr. Ylio          902
#  15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)          907
#  20                         Rothschild, Mr. Martin          912
#
#      PassengerClass  Gender   Age
#  5                3    male  14.0
#  10               3    male  27.0
#  15               2  female  24.0
#  20               1    male  55.0  ,
#      SibSp  Parch         Ticket     Fare Cabin Embarked
#  5       0      0           7538   9.2250   NaN        S
#  10      0      0         349220   7.8958   NaN        S
#  15      1      0  SC/PARIS 2167  27.7208   NaN        C
#  20      1      0       PC 17603  59.4000   NaN        C)

# %% [markdown]
# Concatenate count_1 and count_2 and store the result in a variable called concat_2.(Note: Stack count_1 and count_2 side by side)

# %%
#Write your code here
concat_2=pd.concat([count_1,count_2],axis=1)
concat_2
# Out:
#                                              Name  PassengerId  \
# 5                      Svensson, Mr. Johan Cervin          897
# 10                               Ilieff, Mr. Ylio          902
# 15  del Carlo, Mrs. Sebastiano (Argenia Genovesi)          907
# 20                         Rothschild, Mr. Martin          912
#
#     PassengerClass  Gender   Age  SibSp  Parch         Ticket     Fare Cabin  \
# 5                3    male  14.0      0      0           7538   9.2250   NaN
# 10               3    male  27.0      0      0         349220   7.8958   NaN
# 15               2  female  24.0      1      0  SC/PARIS 2167  27.7208   NaN
# 20               1    male  55.0      1      0       PC 17603  59.4000   NaN
#
#    Embarked
# 5         S
# 10        S
# 15        C
# 20        C

# %% [markdown]
# Please use string method and convert the name column to lower case.

# %%
#Write your code here
df_titanic.Name.str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %% [markdown]
# Please use contains string method and find "mr" in passanger name

# %%
#Write your code here
df_titanic['containsmr']=df_titanic.Name.str.contains("mr")
df_titanic
# Out:
#                                              Name  PassengerId  \
# 0                                Kelly, Mr. James          892
# 1                Wilkes, Mrs. James (Ellen Needs)          893
# 2                       Myles, Mr. Thomas Francis          894
# 3                                Wirz, Mr. Albert          895
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896
# ..                                            ...          ...
# 413                            Spector, Mr. Woolf         1305
# 414                  Oliva y Ocana, Dona. Fermina         1306
# 415                  Saether, Mr. Simon Sivertsen         1307
# 416                           Ware, Mr. Frederick         1308
# 417                      Peter, Master. Michael J         1309
#
#      PassengerClass  Gender   Age  SibSp  Parch              Ticket      Fare  \
# 0                 3    male  34.5      0      0              330911    7.8292
# ...

# %% [markdown]
# # Andvanced Pandas -- Part 2
#
# In this practice exercise, we will analyze Chipotle order data.  The file "Chipotle.tsv" contains this information in a tab separated file.  First, read in the data.  You might find the delimiter input to the pandas read_csv method useful. Use the head method to check that everything has been read in correctly.

# %%
import pandas as pd
import numpy as np

#Write your code here
df_chipotle=pd.read_csv("data/chipotle_orders.tsv",delimiter="\t")
df_chipotle
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# Now take a look at the dtypes attribute to see how the columns are stored.

# %%
#Write your code here
df_chipotle.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %% [markdown]
# Find min and max values of quantity and item price by using apply method

# %%
df_chipotle[['quantity','item_price']].apply([min,max],axis=0)
# Out:
#      quantity item_price
# min         1     $1.09
# max        15     $9.39

# %% [markdown]
# We will write code to answer the following questions:
#
# 1. What fraction of customers order burritos versus burrito bowls?
# 2. What is the average amount of money spent on a Chipotle order?

# %% [markdown]
# For question 1, we will use the apply method to create a column that will read "Burrito" for items that are a burrito, "Bowl" for items that are a bowl and "Other" for every other item.

# %%
#Write your code here

def readchipotle(row):
    
    eat=row['item_name'].lower()
    
    if "burrito" in eat:
        return "Burrito"
    elif "bowl" in eat:
        return "Bowl"
    else:
        return "Other"

# %% [markdown]
# Create new column called "Bowl_Burrito" and compute fractions of bowl versus burrito orders. The value_counts() method could be useful here.

# %%
#Write you code here
df_chipotle["Bowl_Burrito"] = df_chipotle.apply(readchipotle, axis=1)
df_chipotle.head()
df_chipotle['Bowl_Burrito']
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price Bowl_Burrito
# 0                                                NaN     $2.39         Other
# 1                                       [Clementine]     $3.39         Other
# 2                                            [Apple]     $3.39         Other
# 3                                                NaN     $2.39         Other
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98          Bowl
# 0         Other
# 1         Other
# 2         Other
# 3         Other
# 4          Bowl
#          ...
# 4617    Burrito
# 4618    Burrito
# ...

# %%
fraction=df_chipotle['Bowl_Burrito'].value_counts().Bowl/df_chipotle['Bowl_Burrito'].value_counts().Burrito
print(f'The fraction is about {fraction:.2f}')
# Out:
# The fraction is about 1.14

# %% [markdown]
# For question 2, use iterrows to calculate the average price per order. Note that the item price column is a string, so first use string methods plut the as.type() method to recast this column as a float.

# %%
df_chipotle.shape[0]
df_chipotle['item_price']
# Out:
# 4622
# 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
#Write your code here

#Convert item_price to float
df_chipotle['item_price']=df_chipotle['item_price'].str.strip('$').astype('float64')
df_chipotle.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# Bowl_Burrito           object
# dtype: object

# %%
D={}
for index,row in df_chipotle.iterrows():
    
    pricefloat=row['item_price']
    try:
        D[row['order_id']]+=pricefloat/df_chipotle.shape[0]
    except KeyError:
        D[row['order_id']]=pricefloat/df_chipotle.shape[0]

D
# Out:
# {1: 0.0025010817827780182,
#  2: 0.003673734314149719,
#  3: 0.002741237559498053,
#  4: 0.004543487667676331,
#  5: 0.002964084811769797,
#  6: 0.003786239723063609,
#  7: 0.0033967979229770663,
#  8: 0.002353959324967547,
#  9: 0.002308524448290783,
#  10: 0.0028559065339679793,
#  11: 0.0026784941583729988,
#  12: 0.003109043704024232,
#  13: 0.002353959324967547,
#  14: 0.0021808740804846387,
#  15: 0.002353959324967547,
#  16: 0.0023106880138468195,
#  17: 0.0021808740804846387,
#  18: 0.005387278234530507,
#  19: 0.0030073561228905234,
#  20: 0.00783210731285158,
#  21: 0.005054089138900909,
#  22: 0.0028083080917351796,
#  23: 0.0024167027260926007,
#  24: 0.002611423626135872,
#  25: 0.002462137602769364,
#  26: 0.004435309389874513,
#  27: 0.0030073561228905234,
#  28: 0.007291215923842492,
#  29: 0.0038900908697533537,
#  30: 0.005054089138900909,
#  31: 0.0023106880138468195,
#  32: 0.0028083080917351796,
#  33: 0.0028559065339679793,
#  34: 0.006144526179143228,
# ...

# %%
#Run the following code to install pydata

# %%
# !pip install pydata
